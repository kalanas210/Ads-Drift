# %% [markdown]
# # YOLOv8 License Plate Detection

# %%
# missing yolo dep
# !pip install lapx>=0.5.2

# %%
pip install ultralytics
# Out:
# Collecting ultralytics
#   Downloading ultralytics-8.3.65-py3-none-any.whl.metadata (35 kB)
# Requirement already satisfied: numpy>=1.23.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (1.26.4)
# Requirement already satisfied: matplotlib>=3.3.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (3.10.0)
# Requirement already satisfied: opencv-python>=4.6.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (4.10.0.84)
# Requirement already satisfied: pillow>=7.1.2 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (11.1.0)
# Requirement already satisfied: pyyaml>=5.3.1 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (6.0.2)
# Requirement already satisfied: requests>=2.23.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (2.32.3)
# Requirement already satisfied: scipy>=1.4.1 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (1.13.1)
# Requirement already satisfied: torch>=1.8.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (2.5.1+cu121)
# Requirement already satisfied: torchvision>=0.9.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (0.20.1+cu121)
# Requirement already satisfied: tqdm>=4.64.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (4.67.1)
# Requirement already satisfied: psutil in /usr/local/lib/python3.11/dist-packages (from ultralytics) (5.9.5)
# Requirement already satisfied: py-cpuinfo in /usr/local/lib/python3.11/dist-packages (from ultralytics) (9.0.0)
# Requirement already satisfied: pandas>=1.1.4 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (2.2.2)
# Requirement already satisfied: seaborn>=0.11.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (0.13.2)
# Collecting ultralytics-thop>=2.0.0 (from ultralytics)
#   Downloading ultralytics_thop-2.0.14-py3-none-any.whl.metadata (9.4 kB)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics) (4.55.3)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics) (24.2)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics) (3.2.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.1.4->ultralytics) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.1.4->ultralytics) (2024.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.23.0->ultralytics) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests>=2.23.0->ultralytics) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests>=2.23.0->ultralytics) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests>=2.23.0->ultralytics) (2024.12.14)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (3.16.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (4.12.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (3.1.5)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (2024.10.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (12.1.105)
# Requirement already satisfied: triton==3.1.0 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (3.1.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (1.13.1)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /usr/local/lib/python3.11/dist-packages (from nvidia-cusolver-cu12==11.4.5.107->torch>=1.8.0->ultralytics) (12.6.85)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch>=1.8.0->ultralytics) (1.3.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->ultralytics) (1.17.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch>=1.8.0->ultralytics) (3.0.2)
# Downloading ultralytics-8.3.65-py3-none-any.whl (911 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 911.6/911.6 kB 44.1 MB/s eta 0:00:00
# Downloading ultralytics_thop-2.0.14-py3-none-any.whl (26 kB)
# Installing collected packages: ultralytics-thop, ultralytics
# Successfully installed ultralytics-8.3.65 ultralytics-thop-2.0.14

# %%
import cv2 as cv
from glob import glob
import os
import random
from ultralytics import YOLO
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %% [markdown]
# ## Pre-Trained YOLOv8
#
# The regular YOLOv8 training weights do not contain a `number_plate` class and cannot be used directly for a number plate detection:

# %%
# read in video paths
videos = glob('inputs/*.mp4')
print(videos)
# Out:
# []

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# pick pre-trained model
model_pretrained = YOLO('yolov8n.pt')
# Out:
# Downloading https://github.com/ultralytics/assets/releases/download/v8.3.0/yolov8n.pt to 'yolov8n.pt'...
# 100%|██████████| 6.25M/6.25M [00:00<00:00, 317MB/s]

# %%
# read video by index
video = cv.VideoCapture(videos[1])

# get video dims
frame_width = int(video.get(3))
frame_height = int(video.get(4))
size = (frame_width, frame_height)

# Define the codec and create VideoWriter object
fourcc = cv.VideoWriter_fourcc(*'DIVX')
out = cv.VideoWriter('./outputs/uk_dash_2.avi', fourcc, 20.0, size)

# read frames
ret = True

while ret:
    ret, frame = video.read()

    if ret:
        # detect & track objects
        results = model_pretrained.track(frame, persist=True)

        # plot results
        composed = results[0].plot()

        # save video
        out.write(composed)

out.release()
video.release()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-8-cb168422f5b5> in <cell line: 0>()
#       1 # read video by index
# ----> 2 video = cv.VideoCapture(videos[1])
#       3
#       4 # get video dims
#       5 frame_width = int(video.get(3))
#
# IndexError: list index out of range

# %% [markdown]
# ![YOLOv8 License Plate Detection](https://github.com/ayush-raj13/anpr-and-parking-occupancy-analysis/blob/master/Vehicle%20Matching/outputs/uk_dash.webp?raw=1)

# %% [markdown]
# ## Retraining YOLOv8
#
# * [Dataset: Roboflow - License Plate Recognition Computer Vision Project](https://universe.roboflow.com/roboflow-universe-projects/license-plate-recognition-rxg4e)
#
# Download the Dataset with YOLOv8 annotation and point YOLO to the `data.yaml` file that comes with the dataset:

# %% [markdown]
# ```yml
# train: ../train/images
# val: ../valid/images
# test: ../test/images
#
# nc: 1
# names: ['License_Plate']
#
# roboflow:
#   workspace: roboflow-universe-projects
#   project: license-plate-recognition-rxg4e
#   version: 4
#   license: CC BY 4.0
#   url: https://universe.roboflow.com/roboflow-universe-projects/license-plate-recognition-rxg4e/dataset/4
# ```

# %%
# unzip downloaded dataset to `./datasets`
dataset = 'datasets/data.yaml'

# load a model
# backbone = YOLO("yolov8n.yaml")  # build a new model from scratch
backbone = YOLO("yolov8n.pt")  # load a pre-trained model (recommended for training)

# %%
# Use the model
results = backbone.train(data=dataset, epochs=20)  # train the model
# Out:
# New https://pypi.org/project/ultralytics/8.0.176 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.0.173 🚀 Python-3.10.11 torch-2.0.1 CUDA:0 (NVIDIA GeForce GTX 1060 6GB, 6070MiB)
# engine/trainer: task=detect, mode=train, model=yolov8n.pt, data=datasets/data.yaml, epochs=20, patience=50, batch=16, imgsz=640, save=True, save_period=-1, cache=False, device=None, workers=8, project=None, name=None, exist_ok=False, pretrained=True, optimizer=auto, verbose=True, seed=0, deterministic=True, single_cls=False, rect=False, cos_lr=False, close_mosaic=10, resume=False, amp=True, fraction=1.0, profile=False, freeze=None, overlap_mask=True, mask_ratio=4, dropout=0.0, val=True, split=val, save_json=False, save_hybrid=False, conf=None, iou=0.7, max_det=300, half=False, dnn=False, plots=True, source=None, show=False, save_txt=False, save_conf=False, save_crop=False, show_labels=True, show_conf=True, vid_stride=1, stream_buffer=False, line_width=None, visualize=False, augment=False, agnostic_nms=False, classes=None, retina_masks=False, boxes=True, format=torchscript, keras=False, optimize=False, int8=False, dynamic=False, simplify=False, opset=None, workspace=4, nms=False, lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=7.5, cls=0.5, dfl=1.5, pose=12.0, kobj=1.0, label_smoothing=0.0, nbs=64, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, mosaic=1.0, mixup=0.0, copy_paste=0.0, cfg=None, tracker=botsort.yaml, save_dir=runs/detect/train11
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      7360  ultralytics.nn.modules.block.C2f             [32, 32, 1, True]
#   3                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   4                  -1  2     49664  ultralytics.nn.modules.block.C2f             [64, 64, 2, True]
#   5                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   6                  -1  2    197632  ultralytics.nn.modules.block.C2f             [128, 128, 2, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   8                  -1  1    460288  ultralytics.nn.modules.block.C2f             [256, 256, 1, True]
#   9                  -1  1    164608  ultralytics.nn.modules.block.SPPF            [256, 256, 5]
#  10                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  11             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  12                  -1  1    148224  ultralytics.nn.modules.block.C2f             [384, 128, 1]
#  13                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  14             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  15                  -1  1     37248  ultralytics.nn.modules.block.C2f             [192, 64, 1]
#  16                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#  17            [-1, 12]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  18                  -1  1    123648  ultralytics.nn.modules.block.C2f             [192, 128, 1]
#  19                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  20             [-1, 9]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  21                  -1  1    493056  ultralytics.nn.modules.block.C2f             [384, 256, 1]
#  22        [15, 18, 21]  1    751507  ultralytics.nn.modules.head.Detect           [1, [64, 128, 256]]
# Model summary: 225 layers, 3011043 parameters, 3011027 gradients
#
# Transferred 355/355 items from pretrained weights
# Freezing layer 'model.22.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks with YOLOv8n...
# AMP: checks passed ✅
# train: Scanning /opt/app/03_object_detection_with_text_extraction_easyocr/datasets/train/labels.cache... 21173 images, 28 backgrounds, 0 corrupt: 100%|
# val: Scanning /opt/app/03_object_detection_with_text_extraction_easyocr/datasets/valid/labels.cache... 2046 images, 3 backgrounds, 0 corrupt: 100%|████
# Plotting labels to runs/detect/train11/labels.jpg...
# optimizer: AdamW(lr=0.002, momentum=0.9) with parameter groups 57 weight(decay=0.0), 64 weight(decay=0.0005), 63 bias(decay=0.0)
# Image sizes 640 train, 640 val
# Using 8 dataloader workers
# Logging results to runs/detect/train11
# Starting training for 20 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        1/20      2.43G      1.097      0.546       1.17          5        640: 100%|██████████| 1324/1324 [07:28<00:00,  2.95it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 64/64 [00:14<00:00,  4.31it/s]
#                    all       2046       2132      0.969      0.943      0.973      0.654
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        2/20      2.52G      1.121     0.5725      1.186         10        640: 100%|██████████| 1324/1324 [07:18<00:00,  3.02it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 64/64 [00:16<00:00,  3.89it/s]
#                    all       2046       2132      0.937       0.93      0.938      0.622
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        3/20      2.52G      1.134     0.5877       1.19         10        640: 100%|██████████| 1324/1324 [07:09<00:00,  3.08it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 64/64 [00:16<00:00,  3.85it/s]
#                    all       2046       2132       0.96      0.934      0.964      0.641
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        4/20      2.52G       1.13     0.5816      1.191          6        640: 100%|██████████| 1324/1324 [07:19<00:00,  3.01it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 64/64 [00:15<00:00,  4.08it/s]
#                    all       2046       2132      0.974      0.937      0.974      0.667
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        5/20      2.52G      1.121     0.5683      1.183          6        640: 100%|██████████| 1324/1324 [07:15<00:00,  3.04it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 64/64 [00:15<00:00,  4.03it/s]
#                    all       2046       2132      0.964      0.942       0.97      0.665
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        6/20      2.52G      1.106     0.5594      1.174          8        640: 100%|██████████| 1324/1324 [07:01<00:00,  3.14it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 64/64 [00:14<00:00,  4.29it/s]
#                    all       2046       2132      0.971      0.943      0.974      0.648
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        7/20      2.52G      1.095     0.5432      1.168          7        640: 100%|██████████| 1324/1324 [07:05<00:00,  3.11it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 64/64 [00:16<00:00,  3.82it/s]
#                    all       2046       2132      0.959      0.947      0.972      0.671
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        8/20      2.52G      1.086     0.5342       1.16          6        640: 100%|██████████| 1324/1324 [07:22<00:00,  3.00it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 64/64 [00:16<00:00,  3.84it/s]
#                    all       2046       2132      0.972      0.944      0.975      0.674
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        9/20      2.52G      1.083     0.5285      1.159         10        640: 100%|██████████| 1324/1324 [07:21<00:00,  3.00it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 64/64 [00:16<00:00,  3.90it/s]
#                    all       2046       2132      0.979      0.939      0.978      0.673
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       10/20      2.52G      1.059     0.5118      1.149          8        640: 100%|██████████| 1324/1324 [07:20<00:00,  3.01it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 64/64 [00:15<00:00,  4.02it/s]
#                    all       2046       2132      0.974       0.95       0.98      0.681
# Closing dataloader mosaic
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       11/20      2.52G      1.056     0.4414       1.18          7        640: 100%|██████████| 1324/1324 [07:20<00:00,  3.00it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 64/64 [00:16<00:00,  3.90it/s]
#                    all       2046       2132      0.975      0.953       0.98      0.677
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       12/20      2.52G      1.043     0.4275      1.177          5        640: 100%|██████████| 1324/1324 [07:20<00:00,  3.01it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 64/64 [00:16<00:00,  3.87it/s]
#                    all       2046       2132      0.975      0.947      0.975       0.68
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       13/20      2.52G      1.028     0.4208      1.168          5        640: 100%|██████████| 1324/1324 [07:23<00:00,  2.98it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 64/64 [00:16<00:00,  3.95it/s]
#                    all       2046       2132      0.975      0.946      0.979      0.689
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       14/20      2.52G      1.013     0.4082       1.16          5        640: 100%|██████████| 1324/1324 [07:21<00:00,  3.00it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 64/64 [00:16<00:00,  3.83it/s]
#                    all       2046       2132      0.981      0.955      0.981      0.695
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       15/20      2.52G      1.004     0.3978      1.156          6        640: 100%|██████████| 1324/1324 [07:19<00:00,  3.02it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 64/64 [00:17<00:00,  3.65it/s]
#                    all       2046       2132      0.979      0.957      0.983      0.694
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       16/20      2.52G       0.99     0.3905      1.149          5        640: 100%|██████████| 1324/1324 [07:19<00:00,  3.01it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 64/64 [00:15<00:00,  4.01it/s]
#                    all       2046       2132      0.975      0.959      0.981      0.692
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       17/20      2.52G     0.9811     0.3801      1.141          5        640: 100%|██████████| 1324/1324 [07:16<00:00,  3.03it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 64/64 [00:17<00:00,  3.69it/s]
#                    all       2046       2132      0.975       0.96      0.984      0.699
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       18/20      2.52G      0.967     0.3718       1.13          7        640: 100%|██████████| 1324/1324 [07:20<00:00,  3.00it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 64/64 [00:16<00:00,  3.85it/s]
#                    all       2046       2132      0.985      0.955      0.983      0.696
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       19/20      2.52G     0.9531     0.3614      1.123          5        640: 100%|██████████| 1324/1324 [07:21<00:00,  3.00it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 64/64 [00:16<00:00,  3.94it/s]
#                    all       2046       2132      0.986      0.954      0.984      0.701
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       20/20      2.52G     0.9454     0.3542      1.119          5        640: 100%|██████████| 1324/1324 [07:20<00:00,  3.01it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 64/64 [00:16<00:00,  3.81it/s]
#                    all       2046       2132      0.979      0.959      0.984      0.699
#
# 20 epochs completed in 2.530 hours.
# Optimizer stripped from runs/detect/train11/weights/last.pt, 6.2MB
# Optimizer stripped from runs/detect/train11/weights/best.pt, 6.2MB
#
# Validating runs/detect/train11/weights/best.pt...
# Ultralytics YOLOv8.0.173 🚀 Python-3.10.11 torch-2.0.1 CUDA:0 (NVIDIA GeForce GTX 1060 6GB, 6070MiB)
# Model summary (fused): 168 layers, 3005843 parameters, 0 gradients
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 64/64 [00:17<00:00,  3.61it/s]
#                    all       2046       2132      0.986      0.954      0.984      0.701
# Speed: 0.3ms preprocess, 5.1ms inference, 0.0ms loss, 0.5ms postprocess per image
# Results saved to runs/detect/train11

# %% [markdown]
# ![YOLOv8 License Plate Detection](https://github.com/ayush-raj13/anpr-and-parking-occupancy-analysis/blob/master/Vehicle%20Matching/outputs/results.webp?raw=1)
#
#
# | Class | Images | Instances | Box( P | R | mAP50 | mAP50-95) |
# | -- |  -- |  -- | -- | -- | -- | -- |
# | all |  2046 |  2132 | 0.986 | 0.954 | 0.984 | 0.701 |
# | _Speed: 0.3ms preprocess, 5.1ms inference, 0.0ms loss, 0.5ms postprocess per image_ |
# | _Model summary (fused): 168 layers, 3005843 parameters, 0 gradients_ |

# %%
# Evaluate the model's performance on the validation set
results = backbone.val()
# Out:
# Ultralytics YOLOv8.0.173 🚀 Python-3.10.11 torch-2.0.1 CUDA:0 (NVIDIA GeForce GTX 1060 6GB, 6070MiB)
# Model summary (fused): 168 layers, 3005843 parameters, 0 gradients
# val: Scanning /opt/app/03_object_detection_with_text_extraction_easyocr/datasets/valid/labels.cache... 2046 images, 3 backgrounds, 0 corrupt: 100%|████
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 128/128 [00:18<00:00,  6.74it/s]
#                    all       2046       2132      0.986      0.954      0.984      0.701
# Speed: 0.3ms preprocess, 5.7ms inference, 0.0ms loss, 0.6ms postprocess per image
# Results saved to runs/detect/val

# %% [markdown]
# ![YOLOv8 License Plate Detection](https://github.com/ayush-raj13/anpr-and-parking-occupancy-analysis/blob/master/Vehicle%20Matching/outputs/validation_batch.webp?raw=1)
#
#
# | Class | Images | Instances | Box( P | R | mAP50 | mAP50-95) |
# | -- |  -- |  -- | -- | -- | -- | -- |
# | all |  2046 |  2132 | 0.986 | 0.954 | 0.984 | 0.701 |
# | _Speed: 0.3ms preprocess, 5.7ms inference, 0.0ms loss, 0.6ms postprocess per image_ |

# %%
# Perform object detection on an image using the model
results = backbone('inputs/cars.png')
# Out:
# image 1/1 /opt/app/03_object_detection_with_text_extraction_easyocr/inputs/cars.png: 384x640 2 License_Plates, 35.9ms
# Speed: 1.7ms preprocess, 35.9ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)

# %%
# Export the model to ONNX format
# success = model.export(imgsz=(640, 480), format='onnx', opset=12, optimize=False, half=False)
# Export to PyTorch format
success = backbone.export(imgsz=640, format='torchscript', optimize=False, half=False, int8=False)
# TorchScript: export success ✅ 1.5s, saved as 'runs/detect/train11/weights/best.torchscript' (11.9 MB)
# Out:
# Ultralytics YOLOv8.0.173 🚀 Python-3.10.11 torch-2.0.1 CPU (Intel Core(TM) i7-7700 3.60GHz)
#
# PyTorch: starting from 'runs/detect/train11/weights/best.pt' with input shape (1, 3, 640, 640) BCHW and output shape(s) (1, 5, 8400) (6.0 MB)
#
# TorchScript: starting export with torch 2.0.1...
# TorchScript: export success ✅ 1.3s, saved as 'runs/detect/train11/weights/best.torchscript' (11.9 MB)
#
# Export complete (2.6s)
# Results saved to /opt/app/03_object_detection_with_text_extraction_easyocr/runs/detect/train11/weights
# Predict:         yolo predict task=detect model=runs/detect/train11/weights/best.torchscript imgsz=640
# Validate:        yolo val task=detect model=runs/detect/train11/weights/best.torchscript imgsz=640 data=datasets/data.yaml
# Visualize:       https://netron.app

# %%
# pick pre-trained model
np_model = YOLO('runs/detect/train11/weights/best.torchscript')

# %%
# read video by index
video = cv.VideoCapture(videos[1])
ret, frame = video.read()

# get video dims
frame_width = int(video.get(3))
frame_height = int(video.get(4))
size = (frame_width, frame_height)

# Define the codec and create VideoWriter object
fourcc = cv.VideoWriter_fourcc(*'DIVX')
out = cv.VideoWriter('./outputs/uk_dash_np_2.avi', fourcc, 20.0, size)

# read frames
ret = True

while ret:
    ret, frame = video.read()

    if ret:
        # detect & track objects
        results = np_model.track(frame, persist=True)

        # plot results
        composed = results[0].plot()

        # save video
        out.write(composed)

out.release()
video.release()
# Out:
# 0: 640x640 2 License_Plates, 6.5ms
# Speed: 5.7ms preprocess, 6.5ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 3 License_Plates, 6.4ms
# Speed: 2.9ms preprocess, 6.4ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 2 License_Plates, 8.1ms
# Speed: 2.0ms preprocess, 8.1ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 3 License_Plates, 6.6ms
# Speed: 2.2ms preprocess, 6.6ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 2 License_Plates, 6.7ms
# Speed: 2.2ms preprocess, 6.7ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 3 License_Plates, 6.9ms
# Speed: 2.0ms preprocess, 6.9ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 3 License_Plates, 6.9ms
# Speed: 2.5ms preprocess, 6.9ms inference, 2.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 License_Plate, 7.9ms
# Speed: 2.3ms preprocess, 7.9ms inference, 2.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 License_Plate, 6.7ms
# Speed: 2.1ms preprocess, 6.7ms inference, 3.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 License_Plate, 8.2ms
# Speed: 2.4ms preprocess, 8.2ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 License_Plate, 6.7ms
# Speed: 2.5ms preprocess, 6.7ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 License_Plate, 6.6ms
# Speed: 2.4ms preprocess, 6.6ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 License_Plate, 6.6ms
# Speed: 2.7ms preprocess, 6.6ms inference, 2.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 License_Plate, 6.5ms
# Speed: 2.9ms preprocess, 6.5ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 License_Plate, 7.8ms
# Speed: 2.3ms preprocess, 7.8ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 License_Plate, 6.5ms
# Speed: 2.7ms preprocess, 6.5ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 License_Plate, 6.4ms
# Speed: 2.1ms preprocess, 6.4ms inference, 2.8ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 License_Plate, 7.5ms
# Speed: 2.0ms preprocess, 7.5ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 License_Plate, 6.4ms
# Speed: 2.4ms preprocess, 6.4ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 License_Plate, 6.5ms
# Speed: 2.2ms preprocess, 6.5ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 License_Plate, 6.7ms
# Speed: 3.0ms preprocess, 6.7ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 License_Plate, 6.6ms
# Speed: 2.6ms preprocess, 6.6ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 License_Plate, 8.6ms
# Speed: 2.4ms preprocess, 8.6ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 License_Plate, 6.5ms
# Speed: 2.3ms preprocess, 6.5ms inference, 3.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 License_Plate, 7.1ms
# Speed: 2.3ms preprocess, 7.1ms inference, 2.8ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 License_Plate, 7.0ms
# Speed: 2.9ms preprocess, 7.0ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 License_Plate, 6.5ms
# Speed: 2.3ms preprocess, 6.5ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 License_Plate, 6.7ms
# Speed: 3.0ms preprocess, 6.7ms inference, 3.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 License_Plate, 8.6ms
# Speed: 2.1ms preprocess, 8.6ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 License_Plate, 6.5ms
# Speed: 2.4ms preprocess, 6.5ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 License_Plate, 6.6ms
# Speed: 2.1ms preprocess, 6.6ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 License_Plate, 6.5ms
# Speed: 2.3ms preprocess, 6.5ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 License_Plate, 7.7ms
# Speed: 2.3ms preprocess, 7.7ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 License_Plate, 7.9ms
# Speed: 2.2ms preprocess, 7.9ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 License_Plate, 6.8ms
# Speed: 2.7ms preprocess, 6.8ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 License_Plate, 6.8ms
# Speed: 2.9ms preprocess, 6.8ms inference, 4.3ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 License_Plate, 7.4ms
# Speed: 2.9ms preprocess, 7.4ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 License_Plate, 6.9ms
# Speed: 2.7ms preprocess, 6.9ms inference, 3.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 License_Plate, 6.5ms
# Speed: 2.7ms preprocess, 6.5ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 License_Plate, 6.8ms
# Speed: 2.2ms preprocess, 6.8ms inference, 2.9ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 License_Plate, 8.3ms
# Speed: 2.5ms preprocess, 8.3ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 License_Plate, 6.7ms
# Speed: 2.7ms preprocess, 6.7ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 License_Plate, 7.0ms
# Speed: 2.4ms preprocess, 7.0ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 License_Plate, 6.6ms
# Speed: 3.0ms preprocess, 6.6ms inference, 3.8ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 License_Plate, 6.5ms
# Speed: 2.7ms preprocess, 6.5ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 License_Plate, 6.5ms
# Speed: 2.2ms preprocess, 6.5ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 License_Plate, 6.5ms
# Speed: 2.9ms preprocess, 6.5ms inference, 3.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 License_Plate, 7.8ms
# Speed: 2.1ms preprocess, 7.8ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 License_Plate, 6.5ms
# Speed: 2.7ms preprocess, 6.5ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 License_Plate, 7.4ms
# Speed: 2.8ms preprocess, 7.4ms inference, 2.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 License_Plate, 6.5ms
# Speed: 2.8ms preprocess, 6.5ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 License_Plate, 7.4ms
# Speed: 2.0ms preprocess, 7.4ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 License_Plate, 6.7ms
# Speed: 3.0ms preprocess, 6.7ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 License_Plate, 6.5ms
# Speed: 3.0ms preprocess, 6.5ms inference, 2.4ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 License_Plate, 8.2ms
# Speed: 2.1ms preprocess, 8.2ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 License_Plate, 7.6ms
# Speed: 2.3ms preprocess, 7.6ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 License_Plate, 6.5ms
# Speed: 2.4ms preprocess, 6.5ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 License_Plate, 7.5ms
# Speed: 2.7ms preprocess, 7.5ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 License_Plate, 6.4ms
# Speed: 2.6ms preprocess, 6.4ms inference, 3.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 License_Plate, 6.5ms
# Speed: 3.1ms preprocess, 6.5ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 License_Plate, 8.1ms
# Speed: 2.0ms preprocess, 8.1ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 License_Plate, 6.8ms
# Speed: 2.0ms preprocess, 6.8ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 License_Plate, 7.3ms
# Speed: 2.1ms preprocess, 7.3ms inference, 2.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 License_Plate, 8.2ms
# Speed: 2.0ms preprocess, 8.2ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 License_Plate, 6.6ms
# Speed: 2.7ms preprocess, 6.6ms inference, 3.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 License_Plate, 7.5ms
# Speed: 2.7ms preprocess, 7.5ms inference, 2.8ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 License_Plate, 6.6ms
# Speed: 2.6ms preprocess, 6.6ms inference, 3.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 License_Plate, 7.3ms
# Speed: 2.0ms preprocess, 7.3ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 License_Plate, 6.5ms
# Speed: 2.7ms preprocess, 6.5ms inference, 2.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 License_Plate, 8.3ms
# Speed: 2.8ms preprocess, 8.3ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 License_Plate, 6.6ms
# Speed: 2.1ms preprocess, 6.6ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 License_Plate, 6.5ms
# Speed: 2.2ms preprocess, 6.5ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 License_Plate, 6.6ms
# Speed: 2.2ms preprocess, 6.6ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 License_Plate, 7.8ms
# Speed: 2.5ms preprocess, 7.8ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 License_Plate, 6.6ms
# Speed: 2.6ms preprocess, 6.6ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 License_Plate, 7.7ms
# Speed: 2.1ms preprocess, 7.7ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 License_Plate, 6.5ms
# Speed: 2.5ms preprocess, 6.5ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 License_Plate, 6.6ms
# Speed: 2.6ms preprocess, 6.6ms inference, 2.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 License_Plate, 6.6ms
# Speed: 2.9ms preprocess, 6.6ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 License_Plate, 7.0ms
# Speed: 2.3ms preprocess, 7.0ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 License_Plate, 7.0ms
# Speed: 2.0ms preprocess, 7.0ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 License_Plate, 6.7ms
# Speed: 2.8ms preprocess, 6.7ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 License_Plate, 7.7ms
# Speed: 2.1ms preprocess, 7.7ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 License_Plate, 7.3ms
# Speed: 3.1ms preprocess, 7.3ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 License_Plate, 6.4ms
# Speed: 2.7ms preprocess, 6.4ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 License_Plate, 7.0ms
# Speed: 2.3ms preprocess, 7.0ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 License_Plate, 6.5ms
# Speed: 2.8ms preprocess, 6.5ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 License_Plate, 7.7ms
# Speed: 3.3ms preprocess, 7.7ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 License_Plate, 6.5ms
# Speed: 2.8ms preprocess, 6.5ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 License_Plate, 8.4ms
# Speed: 2.9ms preprocess, 8.4ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 License_Plate, 7.4ms
# Speed: 3.0ms preprocess, 7.4ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 License_Plate, 7.5ms
# Speed: 2.9ms preprocess, 7.5ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 License_Plate, 6.5ms
# Speed: 3.1ms preprocess, 6.5ms inference, 3.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 License_Plate, 7.4ms
# Speed: 3.4ms preprocess, 7.4ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 License_Plate, 7.0ms
# Speed: 2.0ms preprocess, 7.0ms inference, 3.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 License_Plate, 6.7ms
# Speed: 2.2ms preprocess, 6.7ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 License_Plate, 6.7ms
# Speed: 2.4ms preprocess, 6.7ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 License_Plate, 8.2ms
# Speed: 2.0ms preprocess, 8.2ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 License_Plate, 7.6ms
# Speed: 2.7ms preprocess, 7.6ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 License_Plate, 6.7ms
# Speed: 3.1ms preprocess, 6.7ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 License_Plate, 6.9ms
# Speed: 2.6ms preprocess, 6.9ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 License_Plate, 6.9ms
# Speed: 2.6ms preprocess, 6.9ms inference, 3.3ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 License_Plate, 6.9ms
# Speed: 2.7ms preprocess, 6.9ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 License_Plate, 7.0ms
# Speed: 2.9ms preprocess, 7.0ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 License_Plate, 7.1ms
# Speed: 2.5ms preprocess, 7.1ms inference, 2.4ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 License_Plate, 8.2ms
# Speed: 2.3ms preprocess, 8.2ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 License_Plate, 6.5ms
# Speed: 2.2ms preprocess, 6.5ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 License_Plate, 7.5ms
# Speed: 2.5ms preprocess, 7.5ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 License_Plate, 7.6ms
# Speed: 2.2ms preprocess, 7.6ms inference, 2.4ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 License_Plate, 7.3ms
# Speed: 2.3ms preprocess, 7.3ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 License_Plate, 6.6ms
# Speed: 2.3ms preprocess, 6.6ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 License_Plate, 6.5ms
# Speed: 2.9ms preprocess, 6.5ms inference, 2.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 License_Plate, 6.8ms
# Speed: 2.8ms preprocess, 6.8ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 License_Plate, 7.1ms
# Speed: 2.6ms preprocess, 7.1ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 License_Plate, 6.5ms
# Speed: 2.7ms preprocess, 6.5ms inference, 3.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 License_Plate, 6.8ms
# Speed: 2.7ms preprocess, 6.8ms inference, 2.4ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 License_Plate, 6.6ms
# Speed: 3.1ms preprocess, 6.6ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 License_Plate, 6.7ms
# Speed: 2.4ms preprocess, 6.7ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 License_Plate, 7.6ms
# Speed: 2.7ms preprocess, 7.6ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 6.5ms
# Speed: 3.3ms preprocess, 6.5ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 License_Plate, 6.5ms
# Speed: 3.0ms preprocess, 6.5ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 6.6ms
# Speed: 2.6ms preprocess, 6.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 7.4ms
# Speed: 2.3ms preprocess, 7.4ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 License_Plate, 6.9ms
# Speed: 2.3ms preprocess, 6.9ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 License_Plate, 8.2ms
# Speed: 2.1ms preprocess, 8.2ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 8.4ms
# Speed: 2.9ms preprocess, 8.4ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 7.6ms
# Speed: 2.0ms preprocess, 7.6ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 License_Plate, 7.1ms
# Speed: 2.7ms preprocess, 7.1ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 6.4ms
# Speed: 2.6ms preprocess, 6.4ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 6.7ms
# Speed: 2.9ms preprocess, 6.7ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 7.0ms
# Speed: 2.1ms preprocess, 7.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 6.7ms
# Speed: 2.8ms preprocess, 6.7ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 7.0ms
# Speed: 2.1ms preprocess, 7.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 6.8ms
# Speed: 2.8ms preprocess, 6.8ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 6.8ms
# Speed: 2.0ms preprocess, 6.8ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 7.0ms
# Speed: 2.3ms preprocess, 7.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 7.3ms
# Speed: 2.7ms preprocess, 7.3ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 6.8ms
# Speed: 3.0ms preprocess, 6.8ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 License_Plate, 7.4ms
# Speed: 2.1ms preprocess, 7.4ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 6.7ms
# Speed: 2.0ms preprocess, 6.7ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 7.3ms
# Speed: 2.6ms preprocess, 7.3ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 6.5ms
# Speed: 2.7ms preprocess, 6.5ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 6.8ms
# Speed: 2.7ms preprocess, 6.8ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 6.6ms
# Speed: 2.5ms preprocess, 6.6ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 6.6ms
# Speed: 2.0ms preprocess, 6.6ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 7.9ms
# Speed: 2.6ms preprocess, 7.9ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 6.5ms
# Speed: 3.1ms preprocess, 6.5ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 6.5ms
# Speed: 3.0ms preprocess, 6.5ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 6.5ms
# Speed: 2.9ms preprocess, 6.5ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 7.0ms
# Speed: 2.6ms preprocess, 7.0ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 7.5ms
# Speed: 2.5ms preprocess, 7.5ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 6.5ms
# Speed: 3.3ms preprocess, 6.5ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 6.7ms
# Speed: 2.9ms preprocess, 6.7ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 7.4ms
# Speed: 2.3ms preprocess, 7.4ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 7.0ms
# Speed: 2.5ms preprocess, 7.0ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 7.1ms
# Speed: 2.3ms preprocess, 7.1ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 7.6ms
# Speed: 2.3ms preprocess, 7.6ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 6.4ms
# Speed: 2.1ms preprocess, 6.4ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 7.0ms
# Speed: 2.0ms preprocess, 7.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 7.6ms
# Speed: 2.8ms preprocess, 7.6ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 7.0ms
# Speed: 2.5ms preprocess, 7.0ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 6.8ms
# Speed: 2.6ms preprocess, 6.8ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 6.8ms
# Speed: 2.1ms preprocess, 6.8ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 6.5ms
# Speed: 2.4ms preprocess, 6.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 6.6ms
# Speed: 2.7ms preprocess, 6.6ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 7.7ms
# Speed: 2.1ms preprocess, 7.7ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 6.5ms
# Speed: 2.3ms preprocess, 6.5ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 6.5ms
# Speed: 2.8ms preprocess, 6.5ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 7.6ms
# Speed: 2.1ms preprocess, 7.6ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 6.5ms
# Speed: 2.3ms preprocess, 6.5ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 6.5ms
# Speed: 2.1ms preprocess, 6.5ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 6.6ms
# Speed: 2.6ms preprocess, 6.6ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 7.2ms
# Speed: 2.4ms preprocess, 7.2ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 7.0ms
# Speed: 2.5ms preprocess, 7.0ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 6.4ms
# Speed: 2.3ms preprocess, 6.4ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 7.0ms
# Speed: 2.4ms preprocess, 7.0ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 7.0ms
# Speed: 2.8ms preprocess, 7.0ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 6.6ms
# Speed: 2.3ms preprocess, 6.6ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 6.9ms
# Speed: 3.3ms preprocess, 6.9ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 7.0ms
# Speed: 2.1ms preprocess, 7.0ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 7.6ms
# Speed: 2.6ms preprocess, 7.6ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 6.8ms
# Speed: 3.1ms preprocess, 6.8ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 7.1ms
# Speed: 2.2ms preprocess, 7.1ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 6.5ms
# Speed: 2.8ms preprocess, 6.5ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 6.5ms
# Speed: 2.1ms preprocess, 6.5ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 6.5ms
# Speed: 2.9ms preprocess, 6.5ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 6.5ms
# Speed: 2.6ms preprocess, 6.5ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 7.5ms
# Speed: 2.8ms preprocess, 7.5ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 6.4ms
# Speed: 1.9ms preprocess, 6.4ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 6.5ms
# Speed: 2.5ms preprocess, 6.5ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 7.1ms
# Speed: 2.6ms preprocess, 7.1ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 6.5ms
# Speed: 2.5ms preprocess, 6.5ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 7.2ms
# Speed: 2.6ms preprocess, 7.2ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 7.0ms
# Speed: 2.5ms preprocess, 7.0ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 8.1ms
# Speed: 2.6ms preprocess, 8.1ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 7.6ms
# Speed: 2.6ms preprocess, 7.6ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 7.0ms
# Speed: 3.2ms preprocess, 7.0ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 6.5ms
# Speed: 3.0ms preprocess, 6.5ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 7.0ms
# Speed: 2.5ms preprocess, 7.0ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 6.4ms
# Speed: 2.4ms preprocess, 6.4ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 7.6ms
# Speed: 2.9ms preprocess, 7.6ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 6.5ms
# Speed: 2.4ms preprocess, 6.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 6.5ms
# Speed: 2.6ms preprocess, 6.5ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 8.1ms
# Speed: 2.9ms preprocess, 8.1ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 6.7ms
# Speed: 2.3ms preprocess, 6.7ms inference, 2.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 6.8ms
# Speed: 2.5ms preprocess, 6.8ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 7.5ms
# Speed: 2.5ms preprocess, 7.5ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 8.3ms
# Speed: 2.7ms preprocess, 8.3ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 7.1ms
# Speed: 2.3ms preprocess, 7.1ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 6.4ms
# Speed: 2.2ms preprocess, 6.4ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 7.3ms
# Speed: 3.6ms preprocess, 7.3ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 License_Plate, 6.6ms
# Speed: 2.8ms preprocess, 6.6ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 2 License_Plates, 7.7ms
# Speed: 2.8ms preprocess, 7.7ms inference, 2.4ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 2 License_Plates, 6.7ms
# Speed: 3.0ms preprocess, 6.7ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 License_Plate, 7.9ms
# Speed: 2.2ms preprocess, 7.9ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 License_Plate, 6.7ms
# Speed: 2.9ms preprocess, 6.7ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 License_Plate, 7.5ms
# Speed: 2.6ms preprocess, 7.5ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 6.8ms
# Speed: 2.8ms preprocess, 6.8ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 7.8ms
# Speed: 2.7ms preprocess, 7.8ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 7.6ms
# Speed: 2.7ms preprocess, 7.6ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 6.5ms
# Speed: 2.7ms preprocess, 6.5ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 License_Plate, 6.5ms
# Speed: 2.7ms preprocess, 6.5ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 7.9ms
# Speed: 2.8ms preprocess, 7.9ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 7.6ms
# Speed: 2.6ms preprocess, 7.6ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 8.1ms
# Speed: 2.6ms preprocess, 8.1ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 6.4ms
# Speed: 2.1ms preprocess, 6.4ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 8.1ms
# Speed: 2.1ms preprocess, 8.1ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 7.8ms
# Speed: 2.8ms preprocess, 7.8ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 7.7ms
# Speed: 2.8ms preprocess, 7.7ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 7.4ms
# Speed: 3.2ms preprocess, 7.4ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 6.5ms
# Speed: 2.7ms preprocess, 6.5ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 6.5ms
# Speed: 3.6ms preprocess, 6.5ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 7.5ms
# Speed: 2.0ms preprocess, 7.5ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 7.5ms
# Speed: 2.3ms preprocess, 7.5ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 6.5ms
# Speed: 2.8ms preprocess, 6.5ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 8.1ms
# Speed: 2.5ms preprocess, 8.1ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 8.1ms
# Speed: 2.9ms preprocess, 8.1ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 7.7ms
# Speed: 2.4ms preprocess, 7.7ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 7.6ms
# Speed: 2.7ms preprocess, 7.6ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 7.3ms
# Speed: 2.2ms preprocess, 7.3ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 6.5ms
# Speed: 2.9ms preprocess, 6.5ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 6.5ms
# Speed: 2.8ms preprocess, 6.5ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 6.5ms
# Speed: 2.7ms preprocess, 6.5ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 6.9ms
# Speed: 2.8ms preprocess, 6.9ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 License_Plate, 6.5ms
# Speed: 2.0ms preprocess, 6.5ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 License_Plate, 6.5ms
# Speed: 2.3ms preprocess, 6.5ms inference, 2.4ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 License_Plate, 7.3ms
# Speed: 2.7ms preprocess, 7.3ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 License_Plate, 7.7ms
# Speed: 2.2ms preprocess, 7.7ms inference, 3.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 7.9ms
# Speed: 2.6ms preprocess, 7.9ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 7.5ms
# Speed: 3.6ms preprocess, 7.5ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 6.8ms
# Speed: 2.8ms preprocess, 6.8ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 8.8ms
# Speed: 2.0ms preprocess, 8.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 7.0ms
# Speed: 2.3ms preprocess, 7.0ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 7.9ms
# Speed: 2.8ms preprocess, 7.9ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 7.9ms
# Speed: 2.6ms preprocess, 7.9ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 6.5ms
# Speed: 2.3ms preprocess, 6.5ms inference, 2.8ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 6.5ms
# Speed: 2.3ms preprocess, 6.5ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 6.5ms
# Speed: 2.2ms preprocess, 6.5ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 6.4ms
# Speed: 2.4ms preprocess, 6.4ms inference, 3.4ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 6.5ms
# Speed: 2.8ms preprocess, 6.5ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 6.5ms
# Speed: 2.8ms preprocess, 6.5ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 6.5ms
# Speed: 3.1ms preprocess, 6.5ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 8.3ms
# Speed: 2.7ms preprocess, 8.3ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 7.1ms
# Speed: 3.2ms preprocess, 7.1ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 7.2ms
# Speed: 2.9ms preprocess, 7.2ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 6.5ms
# Speed: 2.7ms preprocess, 6.5ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 8.2ms
# Speed: 2.7ms preprocess, 8.2ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 7.7ms
# Speed: 2.7ms preprocess, 7.7ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 7.6ms
# Speed: 2.7ms preprocess, 7.6ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 8.2ms
# Speed: 2.7ms preprocess, 8.2ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 7.6ms
# Speed: 2.8ms preprocess, 7.6ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 7.8ms
# Speed: 2.5ms preprocess, 7.8ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 6.9ms
# Speed: 2.5ms preprocess, 6.9ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 6.5ms
# Speed: 2.2ms preprocess, 6.5ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 8.0ms
# Speed: 2.3ms preprocess, 8.0ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 7.8ms
# Speed: 2.5ms preprocess, 7.8ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 7.2ms
# Speed: 2.9ms preprocess, 7.2ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 8.8ms
# Speed: 2.5ms preprocess, 8.8ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 8.6ms
# Speed: 2.5ms preprocess, 8.6ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 8.7ms
# Speed: 2.3ms preprocess, 8.7ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 8.1ms
# Speed: 3.0ms preprocess, 8.1ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 7.4ms
# Speed: 2.8ms preprocess, 7.4ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 7.5ms
# Speed: 3.4ms preprocess, 7.5ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 7.9ms
# Speed: 2.7ms preprocess, 7.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 6.5ms
# Speed: 2.3ms preprocess, 6.5ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 7.9ms
# Speed: 2.0ms preprocess, 7.9ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 6.9ms
# Speed: 2.5ms preprocess, 6.9ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 6.8ms
# Speed: 2.9ms preprocess, 6.8ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 8.1ms
# Speed: 2.1ms preprocess, 8.1ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 7.8ms
# Speed: 2.5ms preprocess, 7.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 6.5ms
# Speed: 2.1ms preprocess, 6.5ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 6.5ms
# Speed: 2.8ms preprocess, 6.5ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 6.5ms
# Speed: 2.6ms preprocess, 6.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 6.5ms
# Speed: 2.8ms preprocess, 6.5ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 7.8ms
# Speed: 2.1ms preprocess, 7.8ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 6.5ms
# Speed: 2.6ms preprocess, 6.5ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 6.5ms
# Speed: 2.6ms preprocess, 6.5ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 7.7ms
# Speed: 2.2ms preprocess, 7.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 6.4ms
# Speed: 2.0ms preprocess, 6.4ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 8.4ms
# Speed: 2.7ms preprocess, 8.4ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 7.7ms
# Speed: 2.8ms preprocess, 7.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 License_Plate, 7.2ms
# Speed: 2.4ms preprocess, 7.2ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 7.6ms
# Speed: 2.0ms preprocess, 7.6ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 7.6ms
# Speed: 2.6ms preprocess, 7.6ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 6.5ms
# Speed: 2.5ms preprocess, 6.5ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 7.8ms
# Speed: 2.9ms preprocess, 7.8ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 7.5ms
# Speed: 2.5ms preprocess, 7.5ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 7.7ms
# Speed: 2.6ms preprocess, 7.7ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 6.5ms
# Speed: 2.3ms preprocess, 6.5ms inference, 2.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 6.5ms
# Speed: 2.1ms preprocess, 6.5ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 6.7ms
# Speed: 2.8ms preprocess, 6.7ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 7.0ms
# Speed: 2.1ms preprocess, 7.0ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 License_Plate, 6.7ms
# Speed: 2.8ms preprocess, 6.7ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 License_Plate, 7.1ms
# Speed: 2.9ms preprocess, 7.1ms inference, 2.4ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 7.1ms
# Speed: 2.8ms preprocess, 7.1ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 7.2ms
# Speed: 2.9ms preprocess, 7.2ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 License_Plate, 6.6ms
# Speed: 3.2ms preprocess, 6.6ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 License_Plate, 6.8ms
# Speed: 3.0ms preprocess, 6.8ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 6.6ms
# Speed: 2.3ms preprocess, 6.6ms inference, 3.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 6.9ms
# Speed: 2.8ms preprocess, 6.9ms inference, 2.8ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 6.7ms
# Speed: 2.7ms preprocess, 6.7ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 6.7ms
# Speed: 2.9ms preprocess, 6.7ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 6.6ms
# Speed: 2.5ms preprocess, 6.6ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 8.4ms
# Speed: 2.7ms preprocess, 8.4ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 6.5ms
# Speed: 2.5ms preprocess, 6.5ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 6.5ms
# Speed: 2.9ms preprocess, 6.5ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 8.0ms
# Speed: 2.1ms preprocess, 8.0ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 7.4ms
# Speed: 2.9ms preprocess, 7.4ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 7.1ms
# Speed: 2.0ms preprocess, 7.1ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 7.7ms
# Speed: 2.0ms preprocess, 7.7ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 7.4ms
# Speed: 2.1ms preprocess, 7.4ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 7.6ms
# Speed: 2.7ms preprocess, 7.6ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 6.5ms
# Speed: 2.3ms preprocess, 6.5ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 7.2ms
# Speed: 2.3ms preprocess, 7.2ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 6.8ms
# Speed: 3.4ms preprocess, 6.8ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 8.2ms
# Speed: 2.5ms preprocess, 8.2ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 7.7ms
# Speed: 2.3ms preprocess, 7.7ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 7.0ms
# Speed: 2.1ms preprocess, 7.0ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 7.1ms
# Speed: 2.2ms preprocess, 7.1ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 6.9ms
# Speed: 2.9ms preprocess, 6.9ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 7.4ms
# Speed: 2.5ms preprocess, 7.4ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 7.7ms
# Speed: 2.9ms preprocess, 7.7ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 6.7ms
# Speed: 2.3ms preprocess, 6.7ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 6.8ms
# Speed: 2.5ms preprocess, 6.8ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 8.1ms
# Speed: 2.8ms preprocess, 8.1ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 6.5ms
# Speed: 2.5ms preprocess, 6.5ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 6.5ms
# Speed: 2.4ms preprocess, 6.5ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 6.5ms
# Speed: 2.7ms preprocess, 6.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 7.6ms
# Speed: 2.6ms preprocess, 7.6ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 7.8ms
# Speed: 2.3ms preprocess, 7.8ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 6.6ms
# Speed: 2.7ms preprocess, 6.6ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 6.5ms
# Speed: 2.5ms preprocess, 6.5ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 8.3ms
# Speed: 14.4ms preprocess, 8.3ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 7.7ms
# Speed: 2.4ms preprocess, 7.7ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 7.5ms
# Speed: 2.8ms preprocess, 7.5ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 6.6ms
# Speed: 2.5ms preprocess, 6.6ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 License_Plate, 6.9ms
# Speed: 2.2ms preprocess, 6.9ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 License_Plate, 7.0ms
# Speed: 2.2ms preprocess, 7.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 2 License_Plates, 6.4ms
# Speed: 2.0ms preprocess, 6.4ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 2 License_Plates, 7.7ms
# Speed: 2.7ms preprocess, 7.7ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 License_Plate, 7.0ms
# Speed: 2.7ms preprocess, 7.0ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 License_Plate, 7.1ms
# Speed: 2.6ms preprocess, 7.1ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 License_Plate, 7.2ms
# Speed: 2.0ms preprocess, 7.2ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 License_Plate, 6.5ms
# Speed: 2.9ms preprocess, 6.5ms inference, 2.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 License_Plate, 6.5ms
# Speed: 2.4ms preprocess, 6.5ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 License_Plate, 6.5ms
# Speed: 2.5ms preprocess, 6.5ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 License_Plate, 7.1ms
# ...
#
# 0: 640x640 1 License_Plate, 7.0ms
# Speed: 2.2ms preprocess, 7.0ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 License_Plate, 6.9ms
# Speed: 2.7ms preprocess, 6.9ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 License_Plate, 6.8ms
# Speed: 2.0ms preprocess, 6.8ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 License_Plate, 6.8ms
# Speed: 2.0ms preprocess, 6.8ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 License_Plate, 6.9ms
# Speed: 2.1ms preprocess, 6.9ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 License_Plate, 6.4ms
# Speed: 2.8ms preprocess, 6.4ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 License_Plate, 6.4ms
# Speed: 2.0ms preprocess, 6.4ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 License_Plate, 6.4ms
# Speed: 2.0ms preprocess, 6.4ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 License_Plate, 6.4ms
# Speed: 2.1ms preprocess, 6.4ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 License_Plate, 6.4ms
# Speed: 2.1ms preprocess, 6.4ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 License_Plate, 6.5ms
# Speed: 2.1ms preprocess, 6.5ms inference, 2.8ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 License_Plate, 6.4ms
# Speed: 2.5ms preprocess, 6.4ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 License_Plate, 7.4ms
# Speed: 2.7ms preprocess, 7.4ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 License_Plate, 6.7ms
# Speed: 2.0ms preprocess, 6.7ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 License_Plate, 6.7ms
# Speed: 1.9ms preprocess, 6.7ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 License_Plate, 6.4ms
# Speed: 2.4ms preprocess, 6.4ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 License_Plate, 6.9ms
# Speed: 2.0ms preprocess, 6.9ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 License_Plate, 6.5ms
# Speed: 2.3ms preprocess, 6.5ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 License_Plate, 6.4ms
# Speed: 2.1ms preprocess, 6.4ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 License_Plate, 6.7ms
# Speed: 1.9ms preprocess, 6.7ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 License_Plate, 7.6ms
# Speed: 2.2ms preprocess, 7.6ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 License_Plate, 6.9ms
# Speed: 2.1ms preprocess, 6.9ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 License_Plate, 7.1ms
# Speed: 2.2ms preprocess, 7.1ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 License_Plate, 6.8ms
# Speed: 3.0ms preprocess, 6.8ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 License_Plate, 6.9ms
# Speed: 2.2ms preprocess, 6.9ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 License_Plate, 6.5ms
# Speed: 2.1ms preprocess, 6.5ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 License_Plate, 6.6ms
# Speed: 2.5ms preprocess, 6.6ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 License_Plate, 6.9ms
# Speed: 2.2ms preprocess, 6.9ms inference, 2.4ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 License_Plate, 6.4ms
# Speed: 2.0ms preprocess, 6.4ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 License_Plate, 6.7ms
# Speed: 2.6ms preprocess, 6.7ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 License_Plate, 6.6ms
# Speed: 2.3ms preprocess, 6.6ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 License_Plate, 6.4ms
# Speed: 2.3ms preprocess, 6.4ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 License_Plate, 6.5ms
# Speed: 2.3ms preprocess, 6.5ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 License_Plate, 6.5ms
# Speed: 2.1ms preprocess, 6.5ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 License_Plate, 15.7ms
# Speed: 14.3ms preprocess, 15.7ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 License_Plate, 7.8ms
# Speed: 7.7ms preprocess, 7.8ms inference, 4.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 License_Plate, 7.1ms
# Speed: 2.1ms preprocess, 7.1ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 License_Plate, 7.2ms
# Speed: 2.0ms preprocess, 7.2ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 License_Plate, 8.1ms
# Speed: 2.1ms preprocess, 8.1ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 License_Plate, 6.4ms
# Speed: 2.2ms preprocess, 6.4ms inference, 2.4ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 License_Plate, 7.1ms
# Speed: 2.2ms preprocess, 7.1ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 License_Plate, 6.6ms
# Speed: 2.8ms preprocess, 6.6ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 License_Plate, 6.5ms
# Speed: 2.2ms preprocess, 6.5ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 License_Plate, 7.6ms
# Speed: 2.7ms preprocess, 7.6ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 License_Plate, 7.5ms
# Speed: 2.0ms preprocess, 7.5ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 License_Plate, 6.5ms
# Speed: 2.8ms preprocess, 6.5ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 License_Plate, 6.4ms
# Speed: 2.8ms preprocess, 6.4ms inference, 2.4ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 License_Plate, 6.5ms
# Speed: 2.6ms preprocess, 6.5ms inference, 2.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 License_Plate, 7.3ms
# Speed: 2.4ms preprocess, 7.3ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 License_Plate, 6.5ms
# Speed: 2.9ms preprocess, 6.5ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 License_Plate, 6.4ms
# Speed: 3.0ms preprocess, 6.4ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 License_Plate, 6.5ms
# Speed: 2.3ms preprocess, 6.5ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 License_Plate, 7.2ms
# Speed: 2.7ms preprocess, 7.2ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 License_Plate, 6.5ms
# Speed: 2.8ms preprocess, 6.5ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 License_Plate, 6.5ms
# Speed: 2.6ms preprocess, 6.5ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 License_Plate, 7.4ms
# Speed: 2.6ms preprocess, 7.4ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 License_Plate, 6.5ms
# Speed: 2.5ms preprocess, 6.5ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 License_Plate, 6.5ms
# Speed: 2.6ms preprocess, 6.5ms inference, 3.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 License_Plate, 6.5ms
# Speed: 2.5ms preprocess, 6.5ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 License_Plate, 6.7ms
# Speed: 2.0ms preprocess, 6.7ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 License_Plate, 7.8ms
# Speed: 2.1ms preprocess, 7.8ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 License_Plate, 6.5ms
# Speed: 2.7ms preprocess, 6.5ms inference, 2.9ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 License_Plate, 7.7ms
# Speed: 2.9ms preprocess, 7.7ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 License_Plate, 6.5ms
# Speed: 2.7ms preprocess, 6.5ms inference, 2.9ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 License_Plate, 7.2ms
# Speed: 2.8ms preprocess, 7.2ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 License_Plate, 7.1ms
# Speed: 2.4ms preprocess, 7.1ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 License_Plate, 6.4ms
# Speed: 2.7ms preprocess, 6.4ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 License_Plate, 6.9ms
# Speed: 2.1ms preprocess, 6.9ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 License_Plate, 7.6ms
# Speed: 2.0ms preprocess, 7.6ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 License_Plate, 6.5ms
# Speed: 2.5ms preprocess, 6.5ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 License_Plate, 6.5ms
# Speed: 2.8ms preprocess, 6.5ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 License_Plate, 7.4ms
# Speed: 2.0ms preprocess, 7.4ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 License_Plate, 6.5ms
# Speed: 2.3ms preprocess, 6.5ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 License_Plate, 6.4ms
# Speed: 1.9ms preprocess, 6.4ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 License_Plate, 7.5ms
# Speed: 2.0ms preprocess, 7.5ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 License_Plate, 7.3ms
# Speed: 1.9ms preprocess, 7.3ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 License_Plate, 6.4ms
# Speed: 2.4ms preprocess, 6.4ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 License_Plate, 6.4ms
# Speed: 2.2ms preprocess, 6.4ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 License_Plate, 7.1ms
# Speed: 2.5ms preprocess, 7.1ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 License_Plate, 6.5ms
# Speed: 2.2ms preprocess, 6.5ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 License_Plate, 6.5ms
# Speed: 2.7ms preprocess, 6.5ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 License_Plate, 6.6ms
# Speed: 3.0ms preprocess, 6.6ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 License_Plate, 6.5ms
# Speed: 2.8ms preprocess, 6.5ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 License_Plate, 7.4ms
# Speed: 2.6ms preprocess, 7.4ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 License_Plate, 6.5ms
# Speed: 2.9ms preprocess, 6.5ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 License_Plate, 6.6ms
# Speed: 2.7ms preprocess, 6.6ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 License_Plate, 6.5ms
# Speed: 2.6ms preprocess, 6.5ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 License_Plate, 6.5ms
# Speed: 2.2ms preprocess, 6.5ms inference, 2.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 License_Plate, 6.6ms
# Speed: 2.2ms preprocess, 6.6ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 License_Plate, 6.5ms
# Speed: 2.0ms preprocess, 6.5ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 License_Plate, 6.8ms
# Speed: 1.9ms preprocess, 6.8ms inference, 2.4ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 License_Plate, 13.1ms
# Speed: 6.3ms preprocess, 13.1ms inference, 5.3ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 License_Plate, 8.0ms
# Speed: 7.3ms preprocess, 8.0ms inference, 3.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 License_Plate, 6.4ms
# Speed: 1.9ms preprocess, 6.4ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 License_Plate, 6.4ms
# Speed: 2.0ms preprocess, 6.4ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 License_Plate, 7.5ms
# Speed: 2.1ms preprocess, 7.5ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 License_Plate, 6.5ms
# Speed: 3.0ms preprocess, 6.5ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 License_Plate, 7.4ms
# Speed: 2.9ms preprocess, 7.4ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 License_Plate, 6.5ms
# Speed: 2.8ms preprocess, 6.5ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 License_Plate, 7.3ms
# Speed: 2.0ms preprocess, 7.3ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 License_Plate, 7.4ms
# Speed: 1.9ms preprocess, 7.4ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 License_Plate, 7.5ms
# Speed: 2.0ms preprocess, 7.5ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 License_Plate, 6.5ms
# Speed: 2.7ms preprocess, 6.5ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 License_Plate, 7.6ms
# Speed: 2.7ms preprocess, 7.6ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 License_Plate, 7.4ms
# Speed: 2.7ms preprocess, 7.4ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 License_Plate, 7.6ms
# Speed: 2.2ms preprocess, 7.6ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 License_Plate, 7.8ms
# Speed: 2.8ms preprocess, 7.8ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 License_Plate, 6.5ms
# Speed: 2.8ms preprocess, 6.5ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 License_Plate, 7.5ms
# Speed: 2.2ms preprocess, 7.5ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 License_Plate, 7.2ms
# Speed: 2.3ms preprocess, 7.2ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 License_Plate, 6.5ms
# Speed: 2.6ms preprocess, 6.5ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 License_Plate, 6.4ms
# Speed: 2.7ms preprocess, 6.4ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 License_Plate, 6.5ms
# Speed: 2.1ms preprocess, 6.5ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 License_Plate, 7.2ms
# Speed: 2.2ms preprocess, 7.2ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 License_Plate, 7.3ms
# Speed: 2.0ms preprocess, 7.3ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 License_Plate, 6.5ms
# Speed: 1.9ms preprocess, 6.5ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 License_Plate, 6.7ms
# Speed: 2.7ms preprocess, 6.7ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 License_Plate, 6.6ms
# Speed: 2.6ms preprocess, 6.6ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 License_Plate, 6.5ms
# Speed: 2.8ms preprocess, 6.5ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 License_Plate, 6.5ms
# Speed: 2.5ms preprocess, 6.5ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 License_Plate, 6.7ms
# Speed: 2.6ms preprocess, 6.7ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 License_Plate, 6.8ms
# Speed: 2.1ms preprocess, 6.8ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)

# %% [markdown]
# And now we have a model that is only interested in number plates:
#
# ![YOLOv8 License Plate Detection](https://github.com/ayush-raj13/anpr-and-parking-occupancy-analysis/blob/master/Vehicle%20Matching/outputs/uk_dash_np.webp?raw=1)
#
# Though, the confusion matrix shows us that it also sees a lot of plates that do not exist - but at least it does not miss that many:
#
# ![YOLOv8 License Plate Detection](https://github.com/ayush-raj13/anpr-and-parking-occupancy-analysis/blob/master/Vehicle%20Matching/outputs/confusion_matrix_normalized.webp?raw=1)

# %% [markdown]
# ## Improving Training Results

# %%
# unzip downloaded dataset to `./datasets`
dataset = 'datasets/data.yaml'

# load a model
# backbone = YOLO("yolov8n.yaml")  # build a new model from scratch
backbone_small = YOLO("yolov8s.pt")  # load a pre-trained model (recommended for training)

# %%
# Use the model
results_medium = backbone_small.train(data=dataset, epochs=100)  # train the model

# %% [markdown]
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      57/100      4.57G     0.9052     0.3966      1.064          7        640: 100%|██████████| 1324/1324 [13:43<00:00,  1.61it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 64/64 [00:26<00:00,  2.38it/s]
#                    all       2046       2132      0.981      0.968      0.984      0.709

# %%
# pick pre-trained model
np2_model = YOLO('runs/detect/train4/weights/best.pt')

# %%
# Evaluate the model's performance on the validation set
results = np2_model.val()
# Out:
# Ultralytics YOLOv8.0.173 🚀 Python-3.10.11 torch-2.0.1 CUDA:0 (NVIDIA GeForce GTX 1060 6GB, 6070MiB)
# Model summary (fused): 168 layers, 11125971 parameters, 0 gradients
# Downloading https://ultralytics.com/assets/Arial.ttf to '/root/.config/Ultralytics/Arial.ttf'...
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████| 755k/755k [00:00<00:00, 2.35MB/s]
# val: Scanning /opt/app/datasets/valid/labels.cache... 2046 images, 3 backgrounds, 0 corrupt: 100%|██████████| 2046/2046 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 128/128 [00:35<00:00,  3.59it/s]
#                    all       2046       2132      0.981      0.968      0.984       0.71
# Speed: 0.3ms preprocess, 13.4ms inference, 0.0ms loss, 0.6ms postprocess per image
# Results saved to runs/detect/val2
